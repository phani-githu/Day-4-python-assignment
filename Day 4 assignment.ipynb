# %% [markdown]
# # Question 1

# %%
File = open('Assignment example.txt', 'w')
File.write(' I Love LetsUpgrade ')
File.close()

# %%
File = open('Assignment example.txt','r')
print(File.read())
File = open('Assignment example.txt', 'a')
File.write(' Python is the powerful language ')
File.close()
# Out:
#  I Love LetsUpgrade  Python is the powerful language  Python is the powerful language  Python is the powerful language

# %% [markdown]
# # Question 2

# %%
def factorial(n): 
       
    if n == 0: 
        return 1
      
    return n * factorial(n-1) 
   
num = 5; 
print("Factorial of", num, "is", 
factorial(num))
# Out:
# Factorial of 5 is 120
